# %% [markdown]
# <a href="https://colab.research.google.com/github/JeffreyLuo333/ML-Notebooks/blob/main/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-g6xqzeqg
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-g6xqzeqg
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14626 sha256=9bcdc6835175caabeff05519264a0becdfcd850105ac31d21f05ab3db80083d2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4wx_yb_b/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.232672, train error 82.47,  test loss 2.204096, test error 80.70
# Epoch   100, train loss 1.915712, train error 72.50,  test loss 1.759578, test error 69.18
# Epoch   200, train loss 1.905718, train error 71.07,  test loss 1.749405, test error 69.53
# Epoch   300, train loss 1.907633, train error 70.47,  test loss 1.765523, test error 70.40
# Epoch   400, train loss 1.897425, train error 71.82,  test loss 1.739461, test error 68.25
# Epoch   500, train loss 1.900603, train error 72.18,  test loss 1.721378, test error 68.97
# Epoch   600, train loss 1.912770, train error 72.32,  test loss 1.778636, test error 71.90
# Epoch   700, train loss 1.897974, train error 71.90,  test loss 1.727870, test error 68.75
# Epoch   800, train loss 1.894464, train error 71.03,  test loss 1.739131, test error 69.50
# Epoch   900, train loss 1.898018, train error 72.95,  test loss 1.740021, test error 71.40
# Training model with   4 hidden variables
# Epoch     0, train loss 2.280186, train error 89.00,  test loss 2.280267, test error 89.25
# Epoch   100, train loss 1.810857, train error 67.05,  test loss 1.649117, test error 65.38
# Epoch   200, train loss 1.789154, train error 65.20,  test loss 1.629502, test error 63.83
# Epoch   300, train loss 1.798939, train error 66.80,  test loss 1.639228, test error 65.55
# Epoch   400, train loss 1.781942, train error 65.57,  test loss 1.635627, test error 64.00
# Epoch   500, train loss 1.784247, train error 64.55,  test loss 1.635944, test error 63.38
# Epoch   600, train loss 1.770823, train error 64.40,  test loss 1.627158, test error 63.42
# Epoch   700, train loss 1.773850, train error 64.40,  test loss 1.624425, test error 62.88
# Epoch   800, train loss 1.767865, train error 64.55,  test loss 1.629712, test error 63.15
# Epoch   900, train loss 1.768911, train error 63.83,  test loss 1.634796, test error 62.60
# Training model with   6 hidden variables
# Epoch     0, train loss 2.276173, train error 86.12,  test loss 2.271962, test error 85.50
# Epoch   100, train loss 1.647296, train error 58.58,  test loss 1.448020, test error 55.75
# Epoch   200, train loss 1.615607, train error 57.78,  test loss 1.429173, test error 54.60
# Epoch   300, train loss 1.596626, train error 56.58,  test loss 1.424543, test error 53.65
# Epoch   400, train loss 1.594265, train error 56.58,  test loss 1.426206, test error 53.42
# Epoch   500, train loss 1.592700, train error 56.22,  test loss 1.426494, test error 54.35
# Epoch   600, train loss 1.587805, train error 56.65,  test loss 1.426652, test error 54.47
# Epoch   700, train loss 1.591727, train error 56.65,  test loss 1.428591, test error 54.60
# Epoch   800, train loss 1.586809, train error 56.67,  test loss 1.426527, test error 54.08
# Epoch   900, train loss 1.587054, train error 56.70,  test loss 1.433850, test error 54.47
# Training model with   8 hidden variables
# Epoch     0, train loss 2.287885, train error 86.70,  test loss 2.285675, test error 87.15
# Epoch   100, train loss 1.638857, train error 58.10,  test loss 1.476617, test error 55.92
# Epoch   200, train loss 1.608212, train error 56.30,  test loss 1.474049, test error 56.62
# Epoch   300, train loss 1.589150, train error 54.62,  test loss 1.471377, test error 56.08
# Epoch   400, train loss 1.581376, train error 54.70,  test loss 1.477995, test error 55.50
# Epoch   500, train loss 1.571276, train error 53.80,  test loss 1.487241, test error 56.30
# Epoch   600, train loss 1.562182, train error 54.20,  test loss 1.487334, test error 56.12
# Epoch   700, train loss 1.548951, train error 53.65,  test loss 1.477279, test error 54.80
# Epoch   800, train loss 1.541299, train error 52.58,  test loss 1.478171, test error 55.05
# Epoch   900, train loss 1.519430, train error 52.33,  test loss 1.478950, test error 54.97
# Training model with  10 hidden variables
# Epoch     0, train loss 2.216043, train error 83.60,  test loss 2.208060, test error 82.75
# Epoch   100, train loss 1.593641, train error 57.22,  test loss 1.504473, test error 57.67
# Epoch   200, train loss 1.547016, train error 53.78,  test loss 1.509152, test error 58.10
# Epoch   300, train loss 1.537391, train error 54.20,  test loss 1.532644, test error 58.58
# Epoch   400, train loss 1.516499, train error 53.33,  test loss 1.523953, test error 58.00
# Epoch   500, train loss 1.507436, train error 53.12,  test loss 1.540765, test error 58.08
# Epoch   600, train loss 1.505123, train error 52.78,  test loss 1.552216, test error 57.85
# Epoch   700, train loss 1.504905, train error 52.80,  test loss 1.549361, test error 57.62
# Epoch   800, train loss 1.503299, train error 53.42,  test loss 1.561451, test error 58.67
# Epoch   900, train loss 1.505435, train error 52.90,  test loss 1.559227, test error 57.58
# Training model with  14 hidden variables
# Epoch     0, train loss 2.221444, train error 81.78,  test loss 2.196037, test error 80.82
# Epoch   100, train loss 1.432206, train error 49.25,  test loss 1.378726, test error 52.45
# Epoch   200, train loss 1.338878, train error 45.33,  test loss 1.340646, test error 49.50
# Epoch   300, train loss 1.308382, train error 44.38,  test loss 1.359193, test error 48.88
# Epoch   400, train loss 1.300787, train error 43.65,  test loss 1.390689, test error 50.08
# Epoch   500, train loss 1.298423, train error 43.97,  test loss 1.389728, test error 50.45
# Epoch   600, train loss 1.278196, train error 42.97,  test loss 1.416562, test error 50.47
# Epoch   700, train loss 1.271214, train error 42.42,  test loss 1.422056, test error 50.15
# Epoch   800, train loss 1.260107, train error 42.60,  test loss 1.427107, test error 50.05
# Epoch   900, train loss 1.261382, train error 43.08,  test loss 1.434806, test error 50.83
# Training model with  18 hidden variables
# Epoch     0, train loss 2.195914, train error 81.65,  test loss 2.175841, test error 81.82
# Epoch   100, train loss 1.398641, train error 47.20,  test loss 1.316035, test error 50.30
# Epoch   200, train loss 1.278388, train error 43.38,  test loss 1.305626, test error 48.10
# Epoch   300, train loss 1.225483, train error 41.45,  test loss 1.345661, test error 48.28
# Epoch   400, train loss 1.200033, train error 40.28,  test loss 1.373150, test error 49.25
# Epoch   500, train loss 1.185370, train error 39.62,  test loss 1.420909, test error 49.70
# Epoch   600, train loss 1.162519, train error 39.20,  test loss 1.447371, test error 50.17
# Epoch   700, train loss 1.143248, train error 38.00,  test loss 1.450466, test error 50.30
# Epoch   800, train loss 1.136924, train error 37.95,  test loss 1.474944, test error 50.42
# Epoch   900, train loss 1.134749, train error 38.83,  test loss 1.518799, test error 51.45
# Training model with  22 hidden variables
# Epoch     0, train loss 2.166708, train error 81.53,  test loss 2.125804, test error 79.75
# Epoch   100, train loss 1.277816, train error 42.03,  test loss 1.268976, test error 47.40
# Epoch   200, train loss 1.158377, train error 37.72,  test loss 1.331900, test error 48.65
# Epoch   300, train loss 1.111021, train error 37.00,  test loss 1.429934, test error 49.20
# Epoch   400, train loss 1.069599, train error 35.60,  test loss 1.470070, test error 49.80
# Epoch   500, train loss 1.038185, train error 34.18,  test loss 1.503532, test error 49.95
# Epoch   600, train loss 1.010815, train error 32.43,  test loss 1.530748, test error 50.00
# Epoch   700, train loss 1.006495, train error 33.55,  test loss 1.567343, test error 49.83
# Epoch   800, train loss 0.986568, train error 32.55,  test loss 1.601508, test error 50.05
# Epoch   900, train loss 0.998072, train error 32.22,  test loss 1.632177, test error 50.28
# Training model with  26 hidden variables
# Epoch     0, train loss 2.253772, train error 83.88,  test loss 2.259746, test error 84.97
# Epoch   100, train loss 1.151227, train error 37.92,  test loss 1.266448, test error 45.47
# Epoch   200, train loss 1.017228, train error 34.30,  test loss 1.391048, test error 47.47
# Epoch   300, train loss 0.947921, train error 31.38,  test loss 1.473153, test error 48.83
# Epoch   400, train loss 0.905779, train error 29.97,  test loss 1.553205, test error 48.42
# Epoch   500, train loss 0.865172, train error 28.88,  test loss 1.669291, test error 49.97
# Epoch   600, train loss 0.852705, train error 28.32,  test loss 1.793493, test error 50.85
# Epoch   700, train loss 0.817938, train error 27.32,  test loss 1.859113, test error 51.00
# Epoch   800, train loss 0.809020, train error 26.32,  test loss 1.915501, test error 51.25
# Epoch   900, train loss 0.803360, train error 26.47,  test loss 1.996966, test error 52.28
# Training model with  30 hidden variables
# Epoch     0, train loss 2.163801, train error 78.75,  test loss 2.142211, test error 79.05
# Epoch   100, train loss 1.118488, train error 36.17,  test loss 1.349605, test error 48.65
# Epoch   200, train loss 0.940830, train error 31.28,  test loss 1.510973, test error 49.75
# Epoch   300, train loss 0.834419, train error 27.72,  test loss 1.701861, test error 52.25
# Epoch   400, train loss 0.780847, train error 26.00,  test loss 1.880822, test error 52.40
# Epoch   500, train loss 0.734996, train error 24.97,  test loss 2.046281, test error 53.15
# Epoch   600, train loss 0.722157, train error 24.95,  test loss 2.210975, test error 54.05
# Epoch   700, train loss 0.682066, train error 22.90,  test loss 2.340113, test error 54.05
# Epoch   800, train loss 0.679435, train error 23.12,  test loss 2.440410, test error 55.38
# Epoch   900, train loss 0.659810, train error 22.35,  test loss 2.502518, test error 54.67
# Training model with  35 hidden variables
# Epoch     0, train loss 2.053858, train error 76.85,  test loss 2.000729, test error 77.53
# Epoch   100, train loss 1.010569, train error 33.15,  test loss 1.422741, test error 50.92
# Epoch   200, train loss 0.823328, train error 27.47,  test loss 1.759170, test error 52.60
# Epoch   300, train loss 0.697541, train error 22.95,  test loss 2.041643, test error 52.53
# Epoch   400, train loss 0.616510, train error 21.05,  test loss 2.445238, test error 55.80
# Epoch   500, train loss 0.544369, train error 18.22,  test loss 2.843373, test error 56.17
# Epoch   600, train loss 0.520111, train error 18.07,  test loss 3.177409, test error 56.80
# Epoch   700, train loss 0.499494, train error 17.15,  test loss 3.551387, test error 58.12
# Epoch   800, train loss 0.472459, train error 16.95,  test loss 3.833684, test error 57.88
# Epoch   900, train loss 0.467830, train error 16.82,  test loss 4.158165, test error 58.05
# Training model with  40 hidden variables
# Epoch     0, train loss 2.108955, train error 77.78,  test loss 2.094163, test error 77.35
# Epoch   100, train loss 0.884548, train error 29.20,  test loss 1.429064, test error 49.08
# Epoch   200, train loss 0.612626, train error 19.93,  test loss 1.931466, test error 50.88
# Epoch   300, train loss 0.491920, train error 16.97,  test loss 2.649859, test error 54.28
# Epoch   400, train loss 0.372337, train error 12.22,  test loss 3.330243, test error 55.62
# Epoch   500, train loss 0.328006, train error 11.07,  test loss 4.094394, test error 56.28
# Epoch   600, train loss 0.304272, train error 10.72,  test loss 4.819719, test error 56.97
# Epoch   700, train loss 0.279932, train error 9.78,  test loss 5.508365, test error 57.60
# Epoch   800, train loss 0.243525, train error 8.70,  test loss 6.204004, test error 57.38
# Epoch   900, train loss 0.217657, train error 7.80,  test loss 6.941140, test error 57.67
# Training model with  45 hidden variables
# Epoch     0, train loss 2.095040, train error 78.62,  test loss 2.057023, test error 77.95
# Epoch   100, train loss 0.812946, train error 26.38,  test loss 1.486663, test error 50.45
# Epoch   200, train loss 0.453918, train error 14.20,  test loss 2.144718, test error 52.33
# Epoch   300, train loss 0.323688, train error 10.62,  test loss 3.270323, test error 54.65
# Epoch   400, train loss 0.219354, train error 7.40,  test loss 4.508690, test error 54.78
# Epoch   500, train loss 0.149080, train error 4.75,  test loss 5.802291, test error 56.65
# Epoch   600, train loss 0.159612, train error 5.47,  test loss 6.862829, test error 55.10
# Epoch   700, train loss 0.193867, train error 6.62,  test loss 7.901046, test error 56.05
# Epoch   800, train loss 0.006734, train error 0.00,  test loss 8.655516, test error 55.45
# Epoch   900, train loss 0.004750, train error 0.00,  test loss 9.129107, test error 55.33
# Training model with  50 hidden variables
# Epoch     0, train loss 2.049570, train error 77.03,  test loss 1.979564, test error 76.20
# Epoch   100, train loss 0.730382, train error 22.45,  test loss 1.598609, test error 51.60
# Epoch   200, train loss 0.369155, train error 11.43,  test loss 2.667022, test error 54.92
# Epoch   300, train loss 0.155759, train error 3.50,  test loss 4.207939, test error 56.58
# Epoch   400, train loss 0.125880, train error 3.72,  test loss 6.066831, test error 56.75
# Epoch   500, train loss 0.014707, train error 0.00,  test loss 7.187707, test error 57.22
# Epoch   600, train loss 0.008795, train error 0.00,  test loss 7.894451, test error 57.58
# Epoch   700, train loss 0.006294, train error 0.00,  test loss 8.404655, test error 57.42
# Epoch   800, train loss 0.004855, train error 0.00,  test loss 8.829071, test error 57.47
# Epoch   900, train loss 0.003869, train error 0.00,  test loss 9.162382, test error 57.33
# Training model with  55 hidden variables
# Epoch     0, train loss 2.068458, train error 77.25,  test loss 2.017160, test error 76.43
# Epoch   100, train loss 0.591942, train error 18.85,  test loss 1.688702, test error 51.33
# Epoch   200, train loss 0.169013, train error 3.10,  test loss 3.092308, test error 54.53
# Epoch   300, train loss 0.032478, train error 0.00,  test loss 4.808424, test error 56.38
# Epoch   400, train loss 0.013063, train error 0.00,  test loss 5.761188, test error 56.80
# Epoch   500, train loss 0.007865, train error 0.00,  test loss 6.349973, test error 56.83
# Epoch   600, train loss 0.005486, train error 0.00,  test loss 6.780608, test error 56.88
# Epoch   700, train loss 0.004120, train error 0.00,  test loss 7.111100, test error 56.80
# Epoch   800, train loss 0.003294, train error 0.00,  test loss 7.387981, test error 56.85
# Epoch   900, train loss 0.002709, train error 0.00,  test loss 7.622471, test error 56.80
# Training model with  60 hidden variables
# Epoch     0, train loss 2.028178, train error 75.75,  test loss 1.971986, test error 76.07
# Epoch   100, train loss 0.524869, train error 15.32,  test loss 1.743253, test error 51.62
# Epoch   200, train loss 0.122901, train error 1.57,  test loss 3.299727, test error 54.03
# Epoch   300, train loss 0.020409, train error 0.00,  test loss 4.620444, test error 53.78
# Epoch   400, train loss 0.009733, train error 0.00,  test loss 5.298416, test error 53.92
# Epoch   500, train loss 0.006117, train error 0.00,  test loss 5.744892, test error 54.28
# Epoch   600, train loss 0.004317, train error 0.00,  test loss 6.069397, test error 53.90
# Epoch   700, train loss 0.003299, train error 0.00,  test loss 6.326791, test error 54.05
# Epoch   800, train loss 0.002644, train error 0.00,  test loss 6.537606, test error 54.03
# Epoch   900, train loss 0.002190, train error 0.00,  test loss 6.723368, test error 53.95
# Training model with  70 hidden variables
# Epoch     0, train loss 2.046280, train error 76.15,  test loss 1.991010, test error 76.75
# Epoch   100, train loss 0.321302, train error 7.53,  test loss 2.091786, test error 53.47
# Epoch   200, train loss 0.027927, train error 0.00,  test loss 3.767385, test error 54.70
# Epoch   300, train loss 0.009871, train error 0.00,  test loss 4.526936, test error 55.03
# Epoch   400, train loss 0.005623, train error 0.00,  test loss 4.953041, test error 54.90
# Epoch   500, train loss 0.003819, train error 0.00,  test loss 5.261429, test error 54.97
# Epoch   600, train loss 0.002846, train error 0.00,  test loss 5.491994, test error 55.08
# Epoch   700, train loss 0.002245, train error 0.00,  test loss 5.677559, test error 55.30
# Epoch   800, train loss 0.001837, train error 0.00,  test loss 5.836251, test error 55.22
# Epoch   900, train loss 0.001549, train error 0.00,  test loss 5.970331, test error 55.33
# Training model with  80 hidden variables
# Epoch     0, train loss 2.029791, train error 75.35,  test loss 1.960035, test error 74.75
# Epoch   100, train loss 0.250581, train error 5.00,  test loss 2.156579, test error 52.53
# Epoch   200, train loss 0.021123, train error 0.00,  test loss 3.521617, test error 53.25
# Epoch   300, train loss 0.008315, train error 0.00,  test loss 4.091846, test error 53.00
# Epoch   400, train loss 0.004904, train error 0.00,  test loss 4.438196, test error 53.33
# Epoch   500, train loss 0.003381, train error 0.00,  test loss 4.679568, test error 53.05
# Epoch   600, train loss 0.002549, train error 0.00,  test loss 4.864982, test error 53.03
# Epoch   700, train loss 0.002015, train error 0.00,  test loss 5.019934, test error 52.92
# Epoch   800, train loss 0.001657, train error 0.00,  test loss 5.144756, test error 52.88
# Epoch   900, train loss 0.001401, train error 0.00,  test loss 5.256122, test error 52.92
# Training model with  90 hidden variables
# Epoch     0, train loss 1.995254, train error 73.60,  test loss 1.929935, test error 74.75
# Epoch   100, train loss 0.132079, train error 1.05,  test loss 2.225523, test error 51.17
# Epoch   200, train loss 0.013952, train error 0.00,  test loss 3.200656, test error 51.10
# Epoch   300, train loss 0.006242, train error 0.00,  test loss 3.610397, test error 51.00
# Epoch   400, train loss 0.003814, train error 0.00,  test loss 3.868793, test error 51.00
# Epoch   500, train loss 0.002691, train error 0.00,  test loss 4.053290, test error 50.90
# Epoch   600, train loss 0.002047, train error 0.00,  test loss 4.197387, test error 50.97
# Epoch   700, train loss 0.001639, train error 0.00,  test loss 4.317783, test error 51.05
# Epoch   800, train loss 0.001358, train error 0.00,  test loss 4.418216, test error 51.08
# Epoch   900, train loss 0.001154, train error 0.00,  test loss 4.505626, test error 51.10
# Training model with 100 hidden variables
# Epoch     0, train loss 1.981080, train error 74.38,  test loss 1.922759, test error 74.57
# Epoch   100, train loss 0.091399, train error 0.10,  test loss 2.297752, test error 51.97
# Epoch   200, train loss 0.011878, train error 0.00,  test loss 3.184467, test error 51.88
# Epoch   300, train loss 0.005578, train error 0.00,  test loss 3.557787, test error 52.03
# Epoch   400, train loss 0.003470, train error 0.00,  test loss 3.787764, test error 52.03
# Epoch   500, train loss 0.002467, train error 0.00,  test loss 3.957470, test error 51.95
# Epoch   600, train loss 0.001890, train error 0.00,  test loss 4.093533, test error 51.78
# Epoch   700, train loss 0.001519, train error 0.00,  test loss 4.204242, test error 51.58
# Epoch   800, train loss 0.001262, train error 0.00,  test loss 4.296404, test error 51.62
# Epoch   900, train loss 0.001074, train error 0.00,  test loss 4.379182, test error 51.62
# Training model with 120 hidden variables
# Epoch     0, train loss 1.958877, train error 72.30,  test loss 1.896889, test error 73.45
# Epoch   100, train loss 0.045330, train error 0.00,  test loss 2.199778, test error 51.20
# Epoch   200, train loss 0.009081, train error 0.00,  test loss 2.772584, test error 51.20
# Epoch   300, train loss 0.004535, train error 0.00,  test loss 3.037977, test error 51.22
# Epoch   400, train loss 0.002911, train error 0.00,  test loss 3.210690, test error 51.08
# Epoch   500, train loss 0.002105, train error 0.00,  test loss 3.338866, test error 51.10
# Epoch   600, train loss 0.001629, train error 0.00,  test loss 3.439726, test error 51.03
# Epoch   700, train loss 0.001319, train error 0.00,  test loss 3.523584, test error 50.90
# Epoch   800, train loss 0.001101, train error 0.00,  test loss 3.594879, test error 50.90
# Epoch   900, train loss 0.000942, train error 0.00,  test loss 3.658013, test error 50.95
# Training model with 140 hidden variables
# Epoch     0, train loss 1.943213, train error 72.30,  test loss 1.871527, test error 72.70
# Epoch   100, train loss 0.036889, train error 0.00,  test loss 2.226786, test error 50.12
# Epoch   200, train loss 0.008171, train error 0.00,  test loss 2.739551, test error 50.03
# Epoch   300, train loss 0.004200, train error 0.00,  test loss 2.978669, test error 50.15
# Epoch   400, train loss 0.002724, train error 0.00,  test loss 3.136867, test error 50.08
# Epoch   500, train loss 0.001980, train error 0.00,  test loss 3.254271, test error 50.10
# Epoch   600, train loss 0.001540, train error 0.00,  test loss 3.346944, test error 50.15
# Epoch   700, train loss 0.001249, train error 0.00,  test loss 3.424968, test error 50.00
# Epoch   800, train loss 0.001046, train error 0.00,  test loss 3.491509, test error 50.08
# Epoch   900, train loss 0.000896, train error 0.00,  test loss 3.548949, test error 50.08
# Training model with 160 hidden variables
# Epoch     0, train loss 1.952453, train error 72.80,  test loss 1.883821, test error 72.50
# Epoch   100, train loss 0.030066, train error 0.00,  test loss 2.101302, test error 47.78
# Epoch   200, train loss 0.007425, train error 0.00,  test loss 2.505371, test error 47.75
# Epoch   300, train loss 0.003884, train error 0.00,  test loss 2.705770, test error 47.88
# Epoch   400, train loss 0.002542, train error 0.00,  test loss 2.837770, test error 47.80
# Epoch   500, train loss 0.001858, train error 0.00,  test loss 2.935780, test error 47.80
# Epoch   600, train loss 0.001450, train error 0.00,  test loss 3.014203, test error 47.67
# Epoch   700, train loss 0.001180, train error 0.00,  test loss 3.078948, test error 47.88
# Epoch   800, train loss 0.000989, train error 0.00,  test loss 3.134473, test error 47.88
# Epoch   900, train loss 0.000849, train error 0.00,  test loss 3.183774, test error 48.00
# Training model with 180 hidden variables
# Epoch     0, train loss 1.917593, train error 70.50,  test loss 1.867737, test error 71.68
# Epoch   100, train loss 0.023314, train error 0.00,  test loss 1.988148, test error 47.85
# Epoch   200, train loss 0.006441, train error 0.00,  test loss 2.322559, test error 47.38
# Epoch   300, train loss 0.003468, train error 0.00,  test loss 2.489142, test error 47.53
# Epoch   400, train loss 0.002303, train error 0.00,  test loss 2.600625, test error 47.33
# Epoch   500, train loss 0.001696, train error 0.00,  test loss 2.685430, test error 47.17
# Epoch   600, train loss 0.001330, train error 0.00,  test loss 2.753590, test error 47.12
# Epoch   700, train loss 0.001086, train error 0.00,  test loss 2.810197, test error 47.15
# Epoch   800, train loss 0.000914, train error 0.00,  test loss 2.858917, test error 47.20
# Epoch   900, train loss 0.000786, train error 0.00,  test loss 2.901350, test error 47.17
# Training model with 200 hidden variables
# Epoch     0, train loss 1.913280, train error 70.20,  test loss 1.849440, test error 71.07
# Epoch   100, train loss 0.021068, train error 0.00,  test loss 2.016965, test error 47.72
# Epoch   200, train loss 0.006095, train error 0.00,  test loss 2.326450, test error 47.22
# Epoch   300, train loss 0.003309, train error 0.00,  test loss 2.488187, test error 47.10
# Epoch   400, train loss 0.002211, train error 0.00,  test loss 2.596307, test error 47.12
# Epoch   500, train loss 0.001634, train error 0.00,  test loss 2.679717, test error 47.28
# Epoch   600, train loss 0.001284, train error 0.00,  test loss 2.745720, test error 47.33
# Epoch   700, train loss 0.001050, train error 0.00,  test loss 2.800555, test error 47.28
# Epoch   800, train loss 0.000884, train error 0.00,  test loss 2.847570, test error 47.33
# Epoch   900, train loss 0.000761, train error 0.00,  test loss 2.888760, test error 47.33
# Training model with 250 hidden variables
# Epoch     0, train loss 1.894610, train error 69.25,  test loss 1.814187, test error 70.68
# Epoch   100, train loss 0.017095, train error 0.00,  test loss 1.892648, test error 45.78
# Epoch   200, train loss 0.005323, train error 0.00,  test loss 2.141336, test error 45.78
# Epoch   300, train loss 0.002970, train error 0.00,  test loss 2.273934, test error 45.92
# Epoch   400, train loss 0.002006, train error 0.00,  test loss 2.362915, test error 45.97
# Epoch   500, train loss 0.001493, train error 0.00,  test loss 2.431234, test error 45.95
# Epoch   600, train loss 0.001179, train error 0.00,  test loss 2.486807, test error 45.97
# Epoch   700, train loss 0.000968, train error 0.00,  test loss 2.532487, test error 45.85
# Epoch   800, train loss 0.000818, train error 0.00,  test loss 2.572732, test error 45.95
# Epoch   900, train loss 0.000705, train error 0.00,  test loss 2.607522, test error 45.92
# Training model with 300 hidden variables
# Epoch     0, train loss 1.853329, train error 66.57,  test loss 1.771530, test error 69.00
# Epoch   100, train loss 0.014535, train error 0.00,  test loss 1.864371, test error 46.15
# Epoch   200, train loss 0.004836, train error 0.00,  test loss 2.086820, test error 46.12
# Epoch   300, train loss 0.002735, train error 0.00,  test loss 2.204963, test error 46.15
# Epoch   400, train loss 0.001863, train error 0.00,  test loss 2.286419, test error 46.08
# Epoch   500, train loss 0.001394, train error 0.00,  test loss 2.348042, test error 46.12
# Epoch   600, train loss 0.001105, train error 0.00,  test loss 2.398319, test error 46.08
# Epoch   700, train loss 0.000910, train error 0.00,  test loss 2.440358, test error 46.12
# Epoch   800, train loss 0.000770, train error 0.00,  test loss 2.476869, test error 46.08
# Epoch   900, train loss 0.000665, train error 0.00,  test loss 2.508545, test error 46.05
# Training model with 400 hidden variables
# Epoch     0, train loss 1.844614, train error 67.22,  test loss 1.777978, test error 68.95
# Epoch   100, train loss 0.011780, train error 0.00,  test loss 1.749523, test error 46.10
# Epoch   200, train loss 0.004195, train error 0.00,  test loss 1.922297, test error 46.08
# Epoch   300, train loss 0.002431, train error 0.00,  test loss 2.018803, test error 46.20
# Epoch   400, train loss 0.001674, train error 0.00,  test loss 2.085299, test error 46.30
# Epoch   500, train loss 0.001261, train error 0.00,  test loss 2.136302, test error 46.20
# Epoch   600, train loss 0.001004, train error 0.00,  test loss 2.178258, test error 46.15
# Epoch   700, train loss 0.000829, train error 0.00,  test loss 2.213003, test error 46.03
# Epoch   800, train loss 0.000704, train error 0.00,  test loss 2.243183, test error 46.03
# Epoch   900, train loss 0.000610, train error 0.00,  test loss 2.270020, test error 46.00

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
